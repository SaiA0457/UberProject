# %%
import pandas as pd

files = [
{"file": "map_cities"},
{"file":"map_cancellation_reasons"},
{"file":"map_payment_methods"},
{"file":"map_ride_statuses"},
{"file":"map_vehicle_makes"},
{"file":"map_vehicle_types"}
]

for file in files:

    url = f"https://saidatalakeuberproject.blob.core.windows.net/raw/ingestion/{file['file']}.json?sp=r&st=2026-03-05T05:29:03Z&se=2026-03-12T13:44:03Z&spr=https&sv=2024-11-04&sr=c&sig=5hVdkFS%2Bn1ljNQ0tJs%2FeO38NGeFhBvqs0HlcDQgZIPU%3D"

    df = pd.read_json(url)
    df_spark = spark.createDataFrame(df)
    
    # Writing Data To the Bronze Layer
    df_spark.write.format("delta")\
            .mode("overwrite")\
            .option("overwriteSchema", "true")\
            .saveAsTable(f"uber.bronze.{file['file']}")

# %%
url = "https://saidatalakeuberproject.blob.core.windows.net/raw/ingestion/bulk_rides.json?sp=r&st=2026-03-05T05:29:03Z&se=2026-03-12T13:44:03Z&spr=https&sv=2024-11-04&sr=c&sig=5hVdkFS%2Bn1ljNQ0tJs%2FeO38NGeFhBvqs0HlcDQgZIPU%3D"

df = pd.read_json(url)
df_spark = spark.createDataFrame(df)
if not spark.catalog.tableExists("uber.bronze.bulk_rides"):
    df_spark.write.format("delta")\
            .mode("overwrite")\
            .saveAsTable(f"uber.bronze.bulk_rides")
    print("This will not run more than 1 time")

# %%
# %sql
SELECT * FROM uber.bronze.map_cities

# %%
# %sql
-- select * from uber.bronze.bulk_rides

# %%
# %sql 
SELECT * FROM uber.bronze.rides_raw
